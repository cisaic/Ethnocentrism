# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 50x50 1 tag

# %%
path50_1_run = '50x50/1-tag/run-1000-100-10'
file50_1_run = !ls $path50_1_run
file50_1_run = [path50_1_run + '/' + file for file in file50_1_run]
file50_1_run
# Out:
# ['50x50/1-tag/run-1000-100-10/behavior-proportions.txt',
#  '50x50/1-tag/run-1000-100-10/behaviors.txt',
#  '50x50/1-tag/run-1000-100-10/strategies.txt',
#  '50x50/1-tag/run-1000-100-10/strategy-proportions.txt']

# %% [markdown]
# # 50x50 2 tags

# %%
path50_2_run = '50x50/2-tag/run-1000-100-10'
file50_2_run = !ls $path50_2_run
file50_2_run = [path50_2_run + '/' + file for file in file50_2_run]
file50_2_run
# Out:
# ['50x50/2-tag/run-1000-100-10/behavior-proportions.txt',
#  '50x50/2-tag/run-1000-100-10/behaviors.txt',
#  '50x50/2-tag/run-1000-100-10/strategies.txt',
#  '50x50/2-tag/run-1000-100-10/strategy-proportions.txt']

# %% [markdown]
# # 50x50 4 tags

# %%
path50_4_run = '50x50/4-tag/run-1000-100-10'
file50_4_run = !ls $path50_4_run
file50_4_run = [path50_4_run + '/' + file for file in file50_4_run]
file50_4_run
# Out:
# ['50x50/4-tag/run-1000-100-10/behavior-proportions.txt',
#  '50x50/4-tag/run-1000-100-10/behaviors.txt',
#  '50x50/4-tag/run-1000-100-10/strategies.txt',
#  '50x50/4-tag/run-1000-100-10/strategy-proportions.txt']

# %% [markdown]
# # 50x50 8 tags

# %%
path50_8_run = '50x50/8-tag/run-1000-100-10'
file50_8_run = !ls $path50_8_run
file50_8_run = [path50_8_run + '/' + file for file in file50_8_run]
file50_8_run
# Out:
# ['50x50/8-tag/run-1000-100-10/behavior-proportions.txt',
#  '50x50/8-tag/run-1000-100-10/behaviors.txt',
#  '50x50/8-tag/run-1000-100-10/strategies.txt',
#  '50x50/8-tag/run-1000-100-10/strategy-proportions.txt']

# %% [markdown]
# # 50x50 10000 tags

# %%
path50_10k_run = '50x50/1000-tag/run-1000-100-10'
file50_10k_run = !ls $path50_10k_run
file50_10k_run = [path50_10k_run + '/' + file for file in file50_10k_run]

# %% [markdown]
# # bp = BEHAVIOUR PROPORTIONS

# %%
file50_1_run
# Out:
# ['50x50/1-tag/run-1000-100-10/behavior-proportions.txt',
#  '50x50/1-tag/run-1000-100-10/behaviors.txt',
#  '50x50/1-tag/run-1000-100-10/strategies.txt',
#  '50x50/1-tag/run-1000-100-10/strategy-proportions.txt']

# %%
# 50x50 1 tag
n50_tags1_bp = pd.read_csv(file50_1_run[0], sep="\t", header=None)
n50_tags1_bp = n50_tags1_bp.drop(2, axis=1)
n50_tags1_bp.columns = ["cooperate", "defect"]
n50_tags1_bp["size"] = 50
n50_tags1_bp["tag"] = 1

# %%
n50_tags1_bp
# Out:
#    cooperate    defect  size  tag
# 0   0.946809  0.053191    50    1
# 1   0.941587  0.058413    50    1
# 2   0.919736  0.080263    50    1
# 3   0.890732  0.109268    50    1
# 4   0.891432  0.108568    50    1
# 5   0.898264  0.101737    50    1
# 6   0.901350  0.098650    50    1
# 7   0.940191  0.059809    50    1
# 8   0.925615  0.074385    50    1
# 9   0.920011  0.079989    50    1

# %%
# 50x50 2 tags

n50_tags2_bp = pd.read_csv(file50_2_run[0], sep="\t", header=None)
n50_tags2_bp = n50_tags2_bp.drop(2, axis=1)
n50_tags2_bp.columns = ["cooperate", "defect"]

#worlds = []
#i = 1
#for row in n10_tags2_bp['cooperate']:
#    worlds.append(i)
#    i = i + 1
#n10_tags2_bp.insert(loc=0, column='world', value=worlds)   

n50_tags2_bp["size"] = 50
n50_tags2_bp["tag"] = 2
n50_tags2_bp
# Out:
#    cooperate    defect  size  tag
# 0   0.792715  0.207285    50    2
# 1   0.819921  0.180079    50    2
# 2   0.779403  0.220597    50    2
# 3   0.815686  0.184314    50    2
# 4   0.784849  0.215151    50    2
# 5   0.789636  0.210364    50    2
# 6   0.785848  0.214152    50    2
# 7   0.793609  0.206390    50    2
# 8   0.787084  0.212916    50    2
# 9   0.775026  0.224974    50    2

# %%
# 50x50 4 tags
n50_tags4_bp = pd.read_csv(file50_4_run[0], sep="\t", header=None)
n50_tags4_bp = n50_tags4_bp.drop(2, axis=1)
n50_tags4_bp.columns = ["cooperate", "defect"]
n50_tags4_bp["size"] = 50
n50_tags4_bp["tag"] = 4

# %%
# 50x50 8 tags
n50_tags8_bp = pd.read_csv(file50_8_run[0], sep="\t", header=None)
n50_tags8_bp = n50_tags8_bp.drop(2, axis=1)
n50_tags8_bp.columns = ["cooperate", "defect"]
n50_tags8_bp["size"] = 50
n50_tags8_bp["tag"] = 8

# %%
# 50x50 1k tags
n50_tags10k_bp = pd.read_csv(file50_10k_run[0], sep="\t", header=None)
n50_tags10k_bp = n50_tags10k_bp.drop(2, axis=1)
n50_tags10k_bp.columns = ["cooperate", "defect"]
n50_tags10k_bp["size"] = 50
n50_tags10k_bp["tag"] = 1000

# %%
n50_bp = n50_tags1_bp
n50_bp = n50_bp.append(n50_tags2_bp)
n50_bp = n50_bp.append(n50_tags4_bp)
n50_bp = n50_bp.append(n50_tags8_bp)
n50_bp = n50_bp.append(n50_tags10k_bp)

# %%
n50_bp_m = pd.melt(n50_bp, id_vars=['tag'], value_vars=['cooperate', 'defect'], var_name='behaviour', value_name='proportion')
n50_bp_m
# Out:
#      tag  behaviour  proportion
# 0      1  cooperate    0.946809
# 1      1  cooperate    0.941587
# 2      1  cooperate    0.919736
# 3      1  cooperate    0.890732
# 4      1  cooperate    0.891432
# 5      1  cooperate    0.898264
# 6      1  cooperate    0.901350
# 7      1  cooperate    0.940191
# 8      1  cooperate    0.925615
# 9      1  cooperate    0.920011
# 10     2  cooperate    0.792715
# 11     2  cooperate    0.819921
# 12     2  cooperate    0.779403
# 13     2  cooperate    0.815686
# 14     2  cooperate    0.784849
# 15     2  cooperate    0.789636
# 16     2  cooperate    0.785848
# 17     2  cooperate    0.793609
# 18     2  cooperate    0.787084
# 19     2  cooperate    0.775026
# 20     4  cooperate    0.728430
# 21     4  cooperate    0.785203
# 22     4  cooperate    0.766901
# 23     4  cooperate    0.783768
# 24     4  cooperate    0.779851
# 25     4  cooperate    0.767066
# 26     4  cooperate    0.754829
# 27     4  cooperate    0.777327
# ...

# %%
# 50x50 box plot behaviour proportions by tag
plt.figure(figsize=(7,7))
sns.boxplot(x='tag', y='proportion', hue='behaviour', data=n50_bp_m)
plt.title("50x50 behaviour proportions by tag")
plt.ylim(top=1.0)
# Out:
# (0.008510427650000006, 1.0)
